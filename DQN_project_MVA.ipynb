# %% [markdown]
# **You may need to install [OpenCV](https://pypi.python.org/pypi/opencv-python) and [scikit-video](http://www.scikit-video.org/stable/).**

# %%
import keras
import numpy as np
import io
import base64
from IPython.display import HTML
import skvideo
skvideo.setFFmpegPath(r"C:\Users\Camille\Desktop\Camille\Cours\3A\MVA\Deep Learning\DM3\ffmpeg-4.1-win64-static\bin")
import skvideo.io
import cv2
import json

from keras.models import Sequential,model_from_json
from keras.layers.core import Dense
from keras.optimizers import sgd
from keras.layers import Conv2D, MaxPooling2D, Activation, AveragePooling2D,Reshape,BatchNormalization, Flatten

# %% [markdown]
# # MiniProject #3: Deep Reinforcement Learning

# %% [markdown]
# __Notations__: $E_p$ is the expectation under probability $p$. Please justify each of your answer and widely comment your code.

# %% [markdown]
# # Context

# %% [markdown]
# In a reinforcement learning algorithm, we modelize each step $t$ as an action $a_t$ obtained from a state $s_t$, i.e. $\{(a_{t},s_{t})_{t\leq T}\}$ having the Markov property. We consider a discount factor $\gamma \in [0,1]$ that ensures convergence. The goal is to find among all the policies $\pi$, one that maximizes the expected reward:
#
# \begin{equation*}
# R(\pi)=\sum_{t\leq T}E_{p^{\pi}}[\gamma^t r(s_{t},a_{t})] \> ,
# \end{equation*}
#
# where:
# \begin{equation*}p^{\pi}(a_{0},a_{1},s_{1},...,a_{T},s_{T})=p(a_{0})\prod_{t=1}^{T}\pi(a_{t}|s_{t})p(s_{t+1}|s_{t},a_{t}) \> .
# \end{equation*}
#
# We note the $Q$-function:
#
# \begin{equation*}Q^\pi(s,a)=E_{p^{\pi}}[\sum_{t\leq T}\gamma^{t}r(s_{t},a_{t})|s_{0}=s,a_{0}=a] \> .
# \end{equation*}
#
# Thus, the optimal Q function is:
# \begin{equation*}
# Q^*(s,a)=\max_{\pi}Q^\pi(s,a) \> .
# \end{equation*}
#
# In this project, we will apply the deep reinforcement learning techniques to a simple game: an agent will have to learn from scratch a policy that will permit it maximizing a reward.

# %% [markdown]
# ## The environment, the agent and the game

# %% [markdown]
# ### The environment

# %% [markdown]
# ```Environment``` is an abstract class that represents the states, rewards, and actions to obtain the new state.

# %%
class Environment(object):
    def __init__(self):
        pass

    def act(self, act):
        """
        One can act on the environment and obtain its reaction:
        - the new state
        - the reward of the new state
        - should we continue the game?

        :return: state, reward, game_over
        """
        pass


    def reset(self):
        """
        Reinitialize the environment to a random state and returns
        the original state

        :return: state
        """
        pass
    
    def draw(self):
        """
        Visualize in the console or graphically the current state
        """
        pass

# %% [markdown]
# The method ```act``` allows to act on the environment at a given state $s_t$ (stored internally), via action $a_t$. The method will return the new state $s_{t+1}$, the reward $r(s_{t},a_{t})$ and determines if $t\leq T$ (*game_over*).
#
# The method ```reset``` simply reinitializes the environment to a random state $s_0$.
#
# The method ```draw``` displays the current state $s_t$ (this is useful to check the behavior of the Agent).
#
# We modelize $s_t$ as a tensor, while $a_t$ is an integer.

# %% [markdown]
# ### The Agent

# %% [markdown]
# The goal of the ```Agent``` is to interact with the ```Environment``` by proposing actions $a_t$ obtained from a given state $s_t$ to attempt to maximize its __reward__ $r(s_t,a_t)$. We propose the following abstract class:

# %%
class Agent(object):
    def __init__(self, epsilon=0.1, n_action=4):
        self.epsilon = epsilon
        self.n_action = n_action
    
    def set_epsilon(self,e):
        self.epsilon = e

    def act(self,s,train=True):
        """ This function should return the next action to do:
        an integer between 0 and 4 (not included) with a random exploration of epsilon"""
        if train:
            if np.random.rand() <= self.epsilon:
                a = np.random.randint(0, self.n_action, size=1)[0]
            else:
                a = self.learned_act(s)
        else: # in some cases, this can improve the performance.. remove it if poor performances
            a = self.learned_act(s)

        return a

    def learned_act(self,s):
        """ Act via the policy of the agent, from a given state s
        it proposes an action a"""
        pass

    def reinforce(self, s, n_s, a, r, game_over_):
        """ This function is the core of the learning algorithm. 
        It takes as an input the current state s_, the next state n_s_
        the action a_ used to move from s_ to n_s_ and the reward r_.
        
        Its goal is to learn a policy.
        """
        pass

    def save(self):
        """ This function returns basic stats if applicable: the
        loss and/or the model"""
        pass

    def load(self):
        """ This function allows to restore a model"""
        pass

# %% [markdown]
# ***
# __Question 1__:
# Explain the function act. Why is ```epsilon``` essential?

# %% [markdown]
# With probability epsilon (which is typically small), we take a random action. With probability 1-epsilon, we stick to the policy we have learnt. The exploration step is important because our policy could be systematically choose suboptimal actions and it's this important to visit all states.

# %% [markdown]
# ***
# ### The Game

# %% [markdown]
# The ```Agent``` and the ```Environment``` work in an interlaced way as in the following (take some time to understand this code as it is the core of the project)
#
# ```python
#
# epoch = 300
# env = Environment()
# agent = Agent()
#
#
# # Number of won games
# score = 0
# loss = 0
#
#
# for e in range(epoch):
#     # At each epoch, we restart to a fresh game and get the initial state
#     state = env.reset()
#     # This assumes that the games will end
#     game_over = False
#
#     win = 0
#     lose = 0
#
#     while not game_over:
#         # The agent performs an action
#         action = agent.act(state)
#
#         # Apply an action to the environment, get the next state, the reward
#         # and if the games end
#         prev_state = state
#         state, reward, game_over = env.act(action)
#
#         # Update the counters
#         if reward > 0:
#             win = win + reward
#         if reward < 0:
#             lose = lose -reward
#
#         # Apply the reinforcement strategy
#         loss = agent.reinforce(prev_state, state,  action, reward, game_over)
#
#     # Save as a mp4
#     if e % 10 == 0:
#         env.draw(e)
#
#     # Update stats
#     score += win-lose
#
#     print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
#           .format(e, epoch, loss, win, lose, win-lose))
#     agent.save()
# ```

# %% [markdown]
# # The game, *eat cheese*

# %% [markdown]
# A rat runs on an island and tries to eat as much as possible. The island is subdivided into $N\times N$ cells, in which there are cheese (+0.5) and poisonous cells (-1). The rat has a visibility of 2 cells (thus it can see $5^2$ cells). The rat is given a time $T$ to accumulate as much food as possible. It can perform 4 actions: going up, down, left, right.
#
# The goal is to code an agent to solve this task that will learn by trial and error. We propose the following environment:

# %%
class Environment(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = self.board[self.x, self.y]
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0

        state = np.concatenate((
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state

# %% [markdown]
# The following elements are important because they correspond to the hyper parameters for this project:

# %%
# parameters
size = 13
T=200
temperature=0.3
epochs_train=100 # set small when debugging
epochs_test=10 # set small when debugging

# display videos
def display_videos(name):
    video = io.open(name, 'r+b').read()
    encoded = base64.b64encode(video)
    return '''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))

# %% [markdown]
# __Question 2__ Explain the use of the arrays ```position``` and ```board```.

# %% [markdown]
# The array board keeps track of the rewards that can either be 0.5 or -1. The array position keeps track of where the rat is at timestep t

# %% [markdown]
# ## Random Agent

# %% [markdown]
# ***
# __Question 3__ Implement a random Agent (only ```learned_act``` needs to be implemented):

# %%
class RandomAgent(Agent):
    def __init__(self):
        super(RandomAgent, self).__init__()
        pass

    def learned_act(self, s):
        return np.random.randint(4)

# %% [markdown]
# ***
# ***
# __Question 4__ Visualize the game moves. You need to fill in the following function for the evaluation:

# %%
def test(agent,env,epochs,prefix=''):
    # Number of won games
    score = 0
        
    for e in range(epochs):
        
        ##### FILL IN HERE
        state = env.reset()
        game_over = False
        
        win = 0
        lose = 0

        while not game_over:
            action = agent.learned_act(state)
            prev_state = state
            state, reward, game_over = env.act(action)
            
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward
          
        # Save as a mp4
        if e%10==0:
            env.draw(prefix+str(e))

        score = score + win-lose

        print("Win/lose count {}/{}. Average score ({})"
              .format(win, lose, score/(1+e)))
        
    print('Final score: '+str(score/epochs))

# %%
# Initialize the game
env = Environment(grid_size=size, max_time=T,temperature=temperature)

# Initialize the agent!
agent = RandomAgent()

test(agent,env,epochs_test,prefix='random')
HTML(display_videos(r'C:\Users\Camille\Desktop\Camille\Cours\3A\MVA\Deep Learning\DM3\random0.mp4'))
# Out:
# Win/lose count 14.5/11.0. Average score (3.5)
# Win/lose count 14.0/12.0. Average score (2.75)
# Win/lose count 10.0/10.0. Average score (1.8333333333333333)
# Win/lose count 15.0/11.0. Average score (2.375)
# Win/lose count 10.5/14.0. Average score (1.2)
# Final score: 1.2
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ## DQN

# %% [markdown]
# Let us assume here that $T=\infty$.
#
# ***
# __Question 5__ Let $\pi$ be a policy, show that:
#
# \begin{equation*}
# Q^{\pi}(s,a)=E_{(s',a')\sim p(.|s,a)}[r(s,a)+\gamma Q^{\pi}(s',a')]
# \end{equation*}
#
# Then, show that for the optimal policy $\pi^*$ (we assume its existence), the following holds:
#
# \begin{equation*}
# Q^{*}(s,a)=E_{s'\sim \pi^*(.|s,a)}[r(s,a)+\gamma\max_{a'}Q^{*}(s',a')].
# \end{equation*}
# Finally, deduce that a plausible objective is:
#
# \begin{equation*}
# \mathcal{L}(\theta)=E_{s' \sim \pi^*(.|s,a)}\Vert r+\gamma\max\max_{a'}Q(s',a',\theta)-Q(s,a,\theta)\Vert^{2}.
# \end{equation*}

# %% [markdown]
# ***
# The DQN-learning algorithm relies on these derivations to train the parameters $\theta$ of a Deep Neural Network:
#
# 1. At the state $s_t$, select the action $a_t$ with best reward using $Q_t$ and store the results;
#
# 2. Obtain the new state $s_{t+1}$ from the environment $p$;
#
# 3. Store $(s_t,a_t,s_{t+1})$;
#
# 4. Obtain $Q_{t+1}$ by minimizing  $\mathcal{L}$ from a recovered batch from the previously stored results.
#
# ***
# __Question 6__ Implement the class ```Memory``` that stores moves (in a replay buffer) via ```remember``` and provides a ```random_access``` to these. Specify a maximum memory size to avoid side effects. You can for example use a ```list()``` and set by default ```max_memory=100```.

# %%
class Memory(object):
    def __init__(self, max_memory=100):
        self.max_memory = max_memory
        self.memory = list()

    def remember(self, m):
        if len(self.memory) < self.max_memory :
            self.memory.append(m)
        else:
            del self.memory[0]
            self.memory.append(m)

    def random_access(self):
        return self.memory[np.random.randint(len(self.memory))]

# %% [markdown]
# ***
# The pipeline we will use for training is given below:

# %%
def train(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')

# %% [markdown]
# ***
# __Question 7__ Implement the DQN training algorithm using a cascade of fully connected layers. You can use different learning rate, batch size or memory size parameters. In particular, the loss might oscillate while the player will start to win the games. You have to find a good criterium.

# %%
class DQN(Agent):
    def __init__(self, grid_size,  epsilon = 0.1, memory_size=100, batch_size = 16,n_state=2):
        super(DQN, self).__init__(epsilon = epsilon)

        # Discount for Q learning
        self.discount = 0.99
        
        self.grid_size = grid_size
        
        # number of state
        self.n_state = n_state

        # Memory
        self.memory = Memory(memory_size)
        
        # Batch size when learning
        self.batch_size = batch_size

    def learned_act(self, s):
        return np.argmax(self.model.predict(np.expand_dims(s, axis = 0)))

    def reinforce(self, s_, n_s_, a_, r_, game_over_):
        # Two steps: first memorize the states, second learn from the pool

        self.memory.remember([s_, n_s_, a_, r_, game_over_])
        
        input_states = np.zeros((self.batch_size, 5,5,self.n_state))
        target_q = np.zeros((self.batch_size, 4))
        
        for i in range(self.batch_size):
            ######## FILL IN
            s_, n_s_, a_, r_, game_over_ = self.memory.random_access()
            input_states[i] = s_
            target_q[i] = self.model.predict(np.expand_dims(s_, axis = 0))
            
            if game_over_:
                ######## FILL IN
                target_q[i][a_] = r_
            else:
                ######## FILL IN
                target_q[i][a_] = r_ + self.discount * np.max(self.model.predict(np.expand_dims(n_s_, axis = 0)))
        ######## FILL IN
        # HINT: Clip the target to avoid exploiding gradients.. -- clipping is a bit tighter
        target_q = np.clip(target_q, -3, 3)

        l = self.model.train_on_batch(input_states, target_q)


        return l

    def save(self,name_weights='model.h5',name_model='model.json'):
        self.model.save_weights(name_weights, overwrite=True)
        with open(name_model, "w") as outfile:
            json.dump(self.model.to_json(), outfile)
            
    def load(self,name_weights='model.h5',name_model='model.json'):
        with open(name_model, "r") as jfile:
            model = model_from_json(json.load(jfile))
        model.load_weights(name_weights)
        model.compile("sgd", "mse")
        self.model = model

            
class DQN_FC(DQN):
    def __init__(self, *args, lr=0.1,**kwargs):
        super(DQN_FC, self).__init__( *args,**kwargs)
        
        # NN Model
        
        ####### FILL IN
        model = Sequential()
        model.add(Flatten(input_shape = (5,5, self.n_state)))
        model.add(Dense(64, activation = 'relu'))
        model.add(Dense(64, activation = 'relu'))

        model.add(Dense(4))


        
        
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent, env, epochs_train, prefix='fc_train')
HTML(display_videos('fc_train10.mp4'))
# Out:
# Epoch 000/150 | Loss 0.0010 | Win/lose count 3.0/6.0 (-3.0)
# Epoch 001/150 | Loss 0.0007 | Win/lose count 3.0/5.0 (-2.0)
# Epoch 002/150 | Loss 0.0409 | Win/lose count 4.5/5.0 (-0.5)
# Epoch 003/150 | Loss 0.0171 | Win/lose count 2.5/4.0 (-1.5)
# Epoch 004/150 | Loss 0.0001 | Win/lose count 4.5/6.0 (-1.5)
# Epoch 005/150 | Loss 0.0075 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 006/150 | Loss 0.0044 | Win/lose count 3.0/5.0 (-2.0)
# Epoch 007/150 | Loss 0.0121 | Win/lose count 2.5/6.0 (-3.5)
# Epoch 008/150 | Loss 0.0073 | Win/lose count 3.0/6.0 (-3.0)
# Epoch 009/150 | Loss 0.0178 | Win/lose count 3.0/2.0 (1.0)
# Epoch 010/150 | Loss 0.0001 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 011/150 | Loss 0.0003 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 012/150 | Loss 0.0097 | Win/lose count 3.5/1.0 (2.5)
# Epoch 013/150 | Loss 0.0000 | Win/lose count 0.5/2.0 (-1.5)
# Epoch 014/150 | Loss 0.0076 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 015/150 | Loss 0.0073 | Win/lose count 2.0/3.0 (-1.0)
# Epoch 016/150 | Loss 0.0065 | Win/lose count 3.0/1.0 (2.0)
# Epoch 017/150 | Loss 0.0021 | Win/lose count 2.5/2.0 (0.5)
# Epoch 018/150 | Loss 0.0000 | Win/lose count 0.5/3.0 (-2.5)
# Epoch 019/150 | Loss 0.0000 | Win/lose count 1.0/5.0 (-4.0)
# Epoch 020/150 | Loss 0.0075 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 021/150 | Loss 0.0078 | Win/lose count 4.0/1.0 (3.0)
# Epoch 022/150 | Loss 0.0037 | Win/lose count 4.0/3.0 (1.0)
# Epoch 023/150 | Loss 0.0001 | Win/lose count 4.5/3.0 (1.5)
# Epoch 024/150 | Loss 0.0076 | Win/lose count 4.0/1.0 (3.0)
# Epoch 025/150 | Loss 0.0077 | Win/lose count 2.5/2.0 (0.5)
# Epoch 026/150 | Loss 0.0002 | Win/lose count 4.5/2.0 (2.5)
# Epoch 027/150 | Loss 0.0061 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 028/150 | Loss 0.0006 | Win/lose count 3.5/0 (3.5)
# Epoch 029/150 | Loss 0.0054 | Win/lose count 3.5/6.0 (-2.5)
# Epoch 030/150 | Loss 0.0022 | Win/lose count 5.0/4.0 (1.0)
# Epoch 031/150 | Loss 0.0100 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 032/150 | Loss 0.0002 | Win/lose count 3.5/3.0 (0.5)
# Epoch 033/150 | Loss 0.0121 | Win/lose count 7.0/5.0 (2.0)
# Epoch 034/150 | Loss 0.0022 | Win/lose count 3.0/3.0 (0.0)
# Epoch 035/150 | Loss 0.0124 | Win/lose count 2.0/1.0 (1.0)
# Epoch 036/150 | Loss 0.0046 | Win/lose count 4.0/1.0 (3.0)
# Epoch 037/150 | Loss 0.0058 | Win/lose count 5.0/4.0 (1.0)
# Epoch 038/150 | Loss 0.0082 | Win/lose count 7.5/2.0 (5.5)
# Epoch 039/150 | Loss 0.0001 | Win/lose count 1.0/4.0 (-3.0)
# Epoch 040/150 | Loss 0.0076 | Win/lose count 2.0/3.0 (-1.0)
# Epoch 041/150 | Loss 0.0056 | Win/lose count 4.0/3.0 (1.0)
# Epoch 042/150 | Loss 0.0134 | Win/lose count 2.0/5.0 (-3.0)
# Epoch 043/150 | Loss 0.0060 | Win/lose count 2.0/3.0 (-1.0)
# Epoch 044/150 | Loss 0.0064 | Win/lose count 3.0/2.0 (1.0)
# Epoch 045/150 | Loss 0.0141 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 046/150 | Loss 0.0080 | Win/lose count 2.0/1.0 (1.0)
# Epoch 047/150 | Loss 0.0080 | Win/lose count 4.0/6.0 (-2.0)
# Epoch 048/150 | Loss 0.0149 | Win/lose count 1.0/2.0 (-1.0)
# Epoch 049/150 | Loss 0.0047 | Win/lose count 4.5/2.0 (2.5)
# Epoch 050/150 | Loss 0.0039 | Win/lose count 8.0/1.0 (7.0)
# Epoch 051/150 | Loss 0.0012 | Win/lose count 5.0/1.0 (4.0)
# Epoch 052/150 | Loss 0.0120 | Win/lose count 4.5/2.0 (2.5)
# Epoch 053/150 | Loss 0.0020 | Win/lose count 2.0/0 (2.0)
# Epoch 054/150 | Loss 0.0020 | Win/lose count 2.5/6.0 (-3.5)
# Epoch 055/150 | Loss 0.0022 | Win/lose count 2.0/3.0 (-1.0)
# Epoch 056/150 | Loss 0.0019 | Win/lose count 2.5/1.0 (1.5)
# Epoch 057/150 | Loss 0.0000 | Win/lose count 3.5/1.0 (2.5)
# Epoch 058/150 | Loss 0.0092 | Win/lose count 3.5/7.0 (-3.5)
# Epoch 059/150 | Loss 0.0024 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 060/150 | Loss 0.0001 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 061/150 | Loss 0.0001 | Win/lose count 3.0/2.0 (1.0)
# Epoch 062/150 | Loss 0.0079 | Win/lose count 4.0/4.0 (0.0)
# Epoch 063/150 | Loss 0.0039 | Win/lose count 3.0/2.0 (1.0)
# Epoch 064/150 | Loss 0.0095 | Win/lose count 2.0/1.0 (1.0)
# Epoch 065/150 | Loss 0.0041 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 066/150 | Loss 0.0035 | Win/lose count 4.5/5.0 (-0.5)
# Epoch 067/150 | Loss 0.0002 | Win/lose count 2.0/2.0 (0.0)
# Epoch 068/150 | Loss 0.0020 | Win/lose count 6.0/5.0 (1.0)
# Epoch 069/150 | Loss 0.0014 | Win/lose count 1.5/2.0 (-0.5)
# Epoch 070/150 | Loss 0.0020 | Win/lose count 3.0/7.0 (-4.0)
# Epoch 071/150 | Loss 0.0001 | Win/lose count 3.5/0 (3.5)
# Epoch 072/150 | Loss 0.0040 | Win/lose count 4.5/4.0 (0.5)
# Epoch 073/150 | Loss 0.0139 | Win/lose count 3.0/2.0 (1.0)
# Epoch 074/150 | Loss 0.0046 | Win/lose count 4.5/4.0 (0.5)
# Epoch 075/150 | Loss 0.0064 | Win/lose count 5.0/7.0 (-2.0)
# Epoch 076/150 | Loss 0.0002 | Win/lose count 5.0/4.0 (1.0)
# Epoch 077/150 | Loss 0.0008 | Win/lose count 4.0/7.0 (-3.0)
# Epoch 078/150 | Loss 0.0145 | Win/lose count 2.0/1.0 (1.0)
# Epoch 079/150 | Loss 0.0061 | Win/lose count 2.5/5.0 (-2.5)
# Epoch 080/150 | Loss 0.0096 | Win/lose count 2.0/3.0 (-1.0)
# Epoch 081/150 | Loss 0.0132 | Win/lose count 4.5/3.0 (1.5)
# Epoch 082/150 | Loss 0.0019 | Win/lose count 6.0/2.0 (4.0)
# Epoch 083/150 | Loss 0.0042 | Win/lose count 4.0/4.0 (0.0)
# Epoch 084/150 | Loss 0.0024 | Win/lose count 6.0/10.0 (-4.0)
# Epoch 085/150 | Loss 0.0001 | Win/lose count 3.0/4.0 (-1.0)
# Epoch 086/150 | Loss 0.0102 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 087/150 | Loss 0.0021 | Win/lose count 4.0/4.0 (0.0)
# Epoch 088/150 | Loss 0.0001 | Win/lose count 4.0/5.0 (-1.0)
# Epoch 089/150 | Loss 0.0191 | Win/lose count 5.0/3.0 (2.0)
# Epoch 090/150 | Loss 0.0020 | Win/lose count 5.5/2.0 (3.5)
# Epoch 091/150 | Loss 0.0031 | Win/lose count 2.0/6.0 (-4.0)
# Epoch 092/150 | Loss 0.0078 | Win/lose count 1.5/1.0 (0.5)
# Epoch 093/150 | Loss 0.0098 | Win/lose count 6.5/6.0 (0.5)
# Epoch 094/150 | Loss 0.0001 | Win/lose count 3.5/3.0 (0.5)
# Epoch 095/150 | Loss 0.0116 | Win/lose count 7.0/5.0 (2.0)
# Epoch 096/150 | Loss 0.0119 | Win/lose count 9.0/3.0 (6.0)
# Epoch 097/150 | Loss 0.0137 | Win/lose count 4.0/3.0 (1.0)
# Epoch 098/150 | Loss 0.0057 | Win/lose count 1.0/3.0 (-2.0)
# Epoch 099/150 | Loss 0.0002 | Win/lose count 6.5/5.0 (1.5)
# Epoch 100/150 | Loss 0.0110 | Win/lose count 4.5/3.0 (1.5)
# Epoch 101/150 | Loss 0.0026 | Win/lose count 3.5/8.0 (-4.5)
# Epoch 102/150 | Loss 0.0051 | Win/lose count 4.5/0 (4.5)
# Epoch 103/150 | Loss 0.0220 | Win/lose count 4.5/4.0 (0.5)
# Epoch 104/150 | Loss 0.0041 | Win/lose count 3.5/3.0 (0.5)
# Epoch 105/150 | Loss 0.0079 | Win/lose count 2.5/2.0 (0.5)
# Epoch 106/150 | Loss 0.0002 | Win/lose count 4.0/3.0 (1.0)
# Epoch 107/150 | Loss 0.0079 | Win/lose count 4.5/2.0 (2.5)
# Epoch 108/150 | Loss 0.0095 | Win/lose count 6.0/4.0 (2.0)
# Epoch 109/150 | Loss 0.0203 | Win/lose count 6.0/7.0 (-1.0)
# Epoch 110/150 | Loss 0.0098 | Win/lose count 2.0/2.0 (0.0)
# Epoch 111/150 | Loss 0.0002 | Win/lose count 6.5/1.0 (5.5)
# Epoch 112/150 | Loss 0.0004 | Win/lose count 3.0/7.0 (-4.0)
# Epoch 113/150 | Loss 0.0021 | Win/lose count 5.5/4.0 (1.5)
# Epoch 114/150 | Loss 0.0145 | Win/lose count 3.0/3.0 (0.0)
# Epoch 115/150 | Loss 0.0048 | Win/lose count 6.5/2.0 (4.5)
# Epoch 116/150 | Loss 0.0144 | Win/lose count 0/4.0 (-4.0)
# Epoch 117/150 | Loss 0.0156 | Win/lose count 1.5/3.0 (-1.5)
# Epoch 118/150 | Loss 0.0056 | Win/lose count 2.0/5.0 (-3.0)
# Epoch 119/150 | Loss 0.0020 | Win/lose count 1.5/4.0 (-2.5)
# Epoch 120/150 | Loss 0.0045 | Win/lose count 1.0/4.0 (-3.0)
# Epoch 121/150 | Loss 0.0020 | Win/lose count 3.0/2.0 (1.0)
# Epoch 122/150 | Loss 0.0018 | Win/lose count 4.5/4.0 (0.5)
# Epoch 123/150 | Loss 0.0152 | Win/lose count 5.0/1.0 (4.0)
# Epoch 124/150 | Loss 0.0041 | Win/lose count 7.5/4.0 (3.5)
# Epoch 125/150 | Loss 0.0266 | Win/lose count 5.0/5.0 (0.0)
# Epoch 126/150 | Loss 0.0091 | Win/lose count 6.0/4.0 (2.0)
# Epoch 127/150 | Loss 0.0115 | Win/lose count 5.0/8.0 (-3.0)
# Epoch 128/150 | Loss 0.0022 | Win/lose count 2.0/2.0 (0.0)
# Epoch 129/150 | Loss 0.0134 | Win/lose count 7.5/2.0 (5.5)
# Epoch 130/150 | Loss 0.0023 | Win/lose count 5.0/4.0 (1.0)
# Epoch 131/150 | Loss 0.0043 | Win/lose count 4.5/2.0 (2.5)
# Epoch 132/150 | Loss 0.0098 | Win/lose count 3.0/3.0 (0.0)
# Epoch 133/150 | Loss 0.0075 | Win/lose count 4.0/1.0 (3.0)
# Epoch 134/150 | Loss 0.0075 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 135/150 | Loss 0.0073 | Win/lose count 4.5/1.0 (3.5)
# Epoch 136/150 | Loss 0.0113 | Win/lose count 2.5/1.0 (1.5)
# Epoch 137/150 | Loss 0.0039 | Win/lose count 3.0/3.0 (0.0)
# Epoch 138/150 | Loss 0.0089 | Win/lose count 1.0/1.0 (0.0)
# Epoch 139/150 | Loss 0.0020 | Win/lose count 5.0/2.0 (3.0)
# Epoch 140/150 | Loss 0.0048 | Win/lose count 2.0/4.0 (-2.0)
# Epoch 141/150 | Loss 0.0001 | Win/lose count 3.0/6.0 (-3.0)
# Epoch 142/150 | Loss 0.0141 | Win/lose count 1.5/1.0 (0.5)
# Epoch 143/150 | Loss 0.0002 | Win/lose count 2.5/3.0 (-0.5)
# Epoch 144/150 | Loss 0.0002 | Win/lose count 2.5/1.0 (1.5)
# Epoch 145/150 | Loss 0.0080 | Win/lose count 6.0/2.0 (4.0)
# Epoch 146/150 | Loss 0.0003 | Win/lose count 3.5/5.0 (-1.5)
# Epoch 147/150 | Loss 0.0097 | Win/lose count 5.0/6.0 (-1.0)
# Epoch 148/150 | Loss 0.0021 | Win/lose count 3.5/1.0 (2.5)
# Epoch 149/150 | Loss 0.0118 | Win/lose count 3.5/1.0 (2.5)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 8__ Implement the DQN training algorithm using a CNN (for example, 2 convolutional layers and one final fully connected layer).

# %%
class DQN_CNN(DQN):
    def __init__(self, *args,lr=0.1,**kwargs):
        super(DQN_CNN, self).__init__(*args,**kwargs)
        
        ###### FILL IN
        model = Sequential()
        model.add(Conv2D(32, (3, 3), activation= 'relu' ,input_shape=(5, 5, self.n_state)))
        model.add(Conv2D(32, (3, 3), activation= 'relu'))
        model.add(Flatten())
        model.add(Dense(4))

        
        model.compile(sgd(lr=lr, decay=1e-4, momentum=0.0), "mse")
        self.model = model

# %%
env = Environment(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
train(agent,env,epochs_train,prefix='cnn_train')
HTML(display_videos('cnn_train10.mp4'))
# Out:
# Epoch 000/150 | Loss 0.0117 | Win/lose count 6.0/5.0 (1.0)
# Epoch 001/150 | Loss 0.0097 | Win/lose count 8.0/4.0 (4.0)
# Epoch 002/150 | Loss 0.0095 | Win/lose count 3.5/1.0 (2.5)
# Epoch 003/150 | Loss 0.0066 | Win/lose count 4.0/0 (4.0)
# Epoch 004/150 | Loss 0.0039 | Win/lose count 7.5/1.0 (6.5)
# Epoch 005/150 | Loss 0.0044 | Win/lose count 4.0/3.0 (1.0)
# Epoch 006/150 | Loss 0.0073 | Win/lose count 5.5/2.0 (3.5)
# Epoch 007/150 | Loss 0.0544 | Win/lose count 5.0/3.0 (2.0)
# Epoch 008/150 | Loss 0.0034 | Win/lose count 6.0/5.0 (1.0)
# Epoch 009/150 | Loss 0.0039 | Win/lose count 7.0/1.0 (6.0)
# Epoch 010/150 | Loss 0.0484 | Win/lose count 9.0/3.0 (6.0)
# Epoch 011/150 | Loss 0.0028 | Win/lose count 15.5/6.0 (9.5)
# Epoch 012/150 | Loss 0.0022 | Win/lose count 6.5/2.0 (4.5)
# Epoch 013/150 | Loss 0.0084 | Win/lose count 10.0/2.0 (8.0)
# Epoch 014/150 | Loss 0.0032 | Win/lose count 9.0/4.0 (5.0)
# Epoch 015/150 | Loss 0.0015 | Win/lose count 7.5/1.0 (6.5)
# Epoch 016/150 | Loss 0.0044 | Win/lose count 11.0/2.0 (9.0)
# Epoch 017/150 | Loss 0.0027 | Win/lose count 6.5/3.0 (3.5)
# Epoch 018/150 | Loss 0.0022 | Win/lose count 16.0/4.0 (12.0)
# Epoch 019/150 | Loss 0.0057 | Win/lose count 13.5/1.0 (12.5)
# Epoch 020/150 | Loss 0.0017 | Win/lose count 4.5/1.0 (3.5)
# Epoch 021/150 | Loss 0.0010 | Win/lose count 6.5/2.0 (4.5)
# Epoch 022/150 | Loss 0.0021 | Win/lose count 14.0/5.0 (9.0)
# Epoch 023/150 | Loss 0.0043 | Win/lose count 12.5/3.0 (9.5)
# Epoch 024/150 | Loss 0.0015 | Win/lose count 11.0/3.0 (8.0)
# Epoch 025/150 | Loss 0.0034 | Win/lose count 10.5/4.0 (6.5)
# Epoch 026/150 | Loss 0.0013 | Win/lose count 12.0/3.0 (9.0)
# Epoch 027/150 | Loss 0.0015 | Win/lose count 16.0/4.0 (12.0)
# Epoch 028/150 | Loss 0.0028 | Win/lose count 16.5/0 (16.5)
# Epoch 029/150 | Loss 0.0024 | Win/lose count 4.5/3.0 (1.5)
# Epoch 030/150 | Loss 0.0033 | Win/lose count 10.5/2.0 (8.5)
# Epoch 031/150 | Loss 0.0015 | Win/lose count 7.0/1.0 (6.0)
# Epoch 032/150 | Loss 0.0042 | Win/lose count 18.0/0 (18.0)
# Epoch 033/150 | Loss 0.0016 | Win/lose count 17.0/2.0 (15.0)
# Epoch 034/150 | Loss 0.0023 | Win/lose count 9.5/3.0 (6.5)
# Epoch 035/150 | Loss 0.0028 | Win/lose count 17.0/0 (17.0)
# Epoch 036/150 | Loss 0.0538 | Win/lose count 9.0/3.0 (6.0)
# Epoch 037/150 | Loss 0.0034 | Win/lose count 10.0/2.0 (8.0)
# Epoch 038/150 | Loss 0.0014 | Win/lose count 18.5/2.0 (16.5)
# Epoch 039/150 | Loss 0.0016 | Win/lose count 14.5/0 (14.5)
# Epoch 040/150 | Loss 0.0020 | Win/lose count 21.5/1.0 (20.5)
# Epoch 041/150 | Loss 0.0032 | Win/lose count 18.5/3.0 (15.5)
# Epoch 042/150 | Loss 0.0024 | Win/lose count 5.5/1.0 (4.5)
# Epoch 043/150 | Loss 0.0031 | Win/lose count 18.5/4.0 (14.5)
# Epoch 044/150 | Loss 0.0022 | Win/lose count 9.5/4.0 (5.5)
# Epoch 045/150 | Loss 0.0022 | Win/lose count 10.5/6.0 (4.5)
# Epoch 046/150 | Loss 0.0028 | Win/lose count 22.5/1.0 (21.5)
# Epoch 047/150 | Loss 0.0027 | Win/lose count 17.5/1.0 (16.5)
# Epoch 048/150 | Loss 0.0013 | Win/lose count 18.0/3.0 (15.0)
# Epoch 049/150 | Loss 0.1108 | Win/lose count 13.5/1.0 (12.5)
# Epoch 050/150 | Loss 0.0014 | Win/lose count 11.5/1.0 (10.5)
# Epoch 051/150 | Loss 0.0011 | Win/lose count 12.5/4.0 (8.5)
# Epoch 052/150 | Loss 0.0031 | Win/lose count 9.0/2.0 (7.0)
# Epoch 053/150 | Loss 0.0023 | Win/lose count 14.5/2.0 (12.5)
# Epoch 054/150 | Loss 0.0029 | Win/lose count 8.0/5.0 (3.0)
# Epoch 055/150 | Loss 0.0016 | Win/lose count 7.5/1.0 (6.5)
# Epoch 056/150 | Loss 0.0029 | Win/lose count 25.5/2.0 (23.5)
# Epoch 057/150 | Loss 0.0041 | Win/lose count 13.5/1.0 (12.5)
# Epoch 058/150 | Loss 0.0029 | Win/lose count 4.5/1.0 (3.5)
# Epoch 059/150 | Loss 0.0035 | Win/lose count 10.5/2.0 (8.5)
# Epoch 060/150 | Loss 0.0023 | Win/lose count 11.5/2.0 (9.5)
# Epoch 061/150 | Loss 0.0012 | Win/lose count 4.5/1.0 (3.5)
# Epoch 062/150 | Loss 0.0018 | Win/lose count 14.0/1.0 (13.0)
# Epoch 063/150 | Loss 0.0018 | Win/lose count 11.0/0 (11.0)
# Epoch 064/150 | Loss 0.0026 | Win/lose count 18.0/1.0 (17.0)
# Epoch 065/150 | Loss 0.0551 | Win/lose count 16.5/0 (16.5)
# Epoch 066/150 | Loss 0.0026 | Win/lose count 10.0/1.0 (9.0)
# Epoch 067/150 | Loss 0.0051 | Win/lose count 11.0/3.0 (8.0)
# Epoch 068/150 | Loss 0.0041 | Win/lose count 19.5/1.0 (18.5)
# Epoch 069/150 | Loss 0.0014 | Win/lose count 12.0/3.0 (9.0)
# Epoch 070/150 | Loss 0.0034 | Win/lose count 15.0/2.0 (13.0)
# Epoch 071/150 | Loss 0.0428 | Win/lose count 16.5/2.0 (14.5)
# Epoch 072/150 | Loss 0.0016 | Win/lose count 9.0/3.0 (6.0)
# Epoch 073/150 | Loss 0.0026 | Win/lose count 18.5/2.0 (16.5)
# Epoch 074/150 | Loss 0.0033 | Win/lose count 14.5/0 (14.5)
# Epoch 075/150 | Loss 0.0034 | Win/lose count 6.5/3.0 (3.5)
# Epoch 076/150 | Loss 0.0009 | Win/lose count 20.0/3.0 (17.0)
# Epoch 077/150 | Loss 0.0063 | Win/lose count 10.0/4.0 (6.0)
# Epoch 078/150 | Loss 0.0012 | Win/lose count 18.0/3.0 (15.0)
# Epoch 079/150 | Loss 0.0101 | Win/lose count 15.5/7.0 (8.5)
# Epoch 080/150 | Loss 0.0560 | Win/lose count 15.0/2.0 (13.0)
# Epoch 081/150 | Loss 0.0037 | Win/lose count 18.5/3.0 (15.5)
# Epoch 082/150 | Loss 0.0025 | Win/lose count 21.0/1.0 (20.0)
# Epoch 083/150 | Loss 0.0533 | Win/lose count 22.5/3.0 (19.5)
# Epoch 084/150 | Loss 0.0034 | Win/lose count 14.0/1.0 (13.0)
# Epoch 085/150 | Loss 0.0031 | Win/lose count 8.0/4.0 (4.0)
# Epoch 086/150 | Loss 0.0041 | Win/lose count 16.0/5.0 (11.0)
# Epoch 087/150 | Loss 0.0027 | Win/lose count 17.5/2.0 (15.5)
# Epoch 088/150 | Loss 0.0022 | Win/lose count 25.0/1.0 (24.0)
# Epoch 089/150 | Loss 0.0015 | Win/lose count 19.5/4.0 (15.5)
# Epoch 090/150 | Loss 0.0546 | Win/lose count 4.0/1.0 (3.0)
# Epoch 091/150 | Loss 0.0024 | Win/lose count 18.0/0 (18.0)
# Epoch 092/150 | Loss 0.0498 | Win/lose count 8.5/5.0 (3.5)
# Epoch 093/150 | Loss 0.0553 | Win/lose count 11.0/1.0 (10.0)
# Epoch 094/150 | Loss 0.0597 | Win/lose count 16.5/2.0 (14.5)
# Epoch 095/150 | Loss 0.0013 | Win/lose count 23.0/2.0 (21.0)
# Epoch 096/150 | Loss 0.0490 | Win/lose count 17.0/0 (17.0)
# Epoch 097/150 | Loss 0.0514 | Win/lose count 21.5/1.0 (20.5)
# Epoch 098/150 | Loss 0.0052 | Win/lose count 13.5/3.0 (10.5)
# Epoch 099/150 | Loss 0.0033 | Win/lose count 9.0/2.0 (7.0)
# Epoch 100/150 | Loss 0.0020 | Win/lose count 15.0/2.0 (13.0)
# Epoch 101/150 | Loss 0.0020 | Win/lose count 17.5/2.0 (15.5)
# Epoch 102/150 | Loss 0.0032 | Win/lose count 25.0/2.0 (23.0)
# Epoch 103/150 | Loss 0.0016 | Win/lose count 10.5/1.0 (9.5)
# Epoch 104/150 | Loss 0.0032 | Win/lose count 12.0/2.0 (10.0)
# Epoch 105/150 | Loss 0.0038 | Win/lose count 15.0/3.0 (12.0)
# Epoch 106/150 | Loss 0.0017 | Win/lose count 8.5/2.0 (6.5)
# Epoch 107/150 | Loss 0.0013 | Win/lose count 15.5/3.0 (12.5)
# Epoch 108/150 | Loss 0.0007 | Win/lose count 13.0/2.0 (11.0)
# Epoch 109/150 | Loss 0.0011 | Win/lose count 9.5/1.0 (8.5)
# Epoch 110/150 | Loss 0.0022 | Win/lose count 4.5/4.0 (0.5)
# Epoch 111/150 | Loss 0.0024 | Win/lose count 12.0/1.0 (11.0)
# Epoch 112/150 | Loss 0.0106 | Win/lose count 18.0/1.0 (17.0)
# Epoch 113/150 | Loss 0.0017 | Win/lose count 21.5/0 (21.5)
# Epoch 114/150 | Loss 0.0015 | Win/lose count 22.0/4.0 (18.0)
# Epoch 115/150 | Loss 0.0013 | Win/lose count 10.0/3.0 (7.0)
# Epoch 116/150 | Loss 0.0016 | Win/lose count 12.0/1.0 (11.0)
# Epoch 117/150 | Loss 0.0018 | Win/lose count 16.5/1.0 (15.5)
# Epoch 118/150 | Loss 0.0019 | Win/lose count 12.0/1.0 (11.0)
# Epoch 119/150 | Loss 0.0023 | Win/lose count 6.0/1.0 (5.0)
# Epoch 120/150 | Loss 0.0023 | Win/lose count 10.5/1.0 (9.5)
# Epoch 121/150 | Loss 0.0038 | Win/lose count 14.5/1.0 (13.5)
# Epoch 122/150 | Loss 0.0021 | Win/lose count 2.5/2.0 (0.5)
# Epoch 123/150 | Loss 0.0021 | Win/lose count 5.5/1.0 (4.5)
# Epoch 124/150 | Loss 0.0028 | Win/lose count 12.5/2.0 (10.5)
# Epoch 125/150 | Loss 0.0021 | Win/lose count 9.5/2.0 (7.5)
# Epoch 126/150 | Loss 0.0016 | Win/lose count 13.0/4.0 (9.0)
# Epoch 127/150 | Loss 0.0017 | Win/lose count 11.0/3.0 (8.0)
# Epoch 128/150 | Loss 0.0013 | Win/lose count 12.5/2.0 (10.5)
# Epoch 129/150 | Loss 0.0017 | Win/lose count 15.0/3.0 (12.0)
# Epoch 130/150 | Loss 0.0023 | Win/lose count 19.0/4.0 (15.0)
# Epoch 131/150 | Loss 0.0550 | Win/lose count 14.5/1.0 (13.5)
# Epoch 132/150 | Loss 0.0010 | Win/lose count 7.5/4.0 (3.5)
# Epoch 133/150 | Loss 0.0012 | Win/lose count 15.5/3.0 (12.5)
# Epoch 134/150 | Loss 0.0035 | Win/lose count 18.5/1.0 (17.5)
# Epoch 135/150 | Loss 0.0018 | Win/lose count 4.5/3.0 (1.5)
# Epoch 136/150 | Loss 0.0021 | Win/lose count 19.0/3.0 (16.0)
# Epoch 137/150 | Loss 0.0022 | Win/lose count 15.5/5.0 (10.5)
# Epoch 138/150 | Loss 0.0042 | Win/lose count 18.0/5.0 (13.0)
# Epoch 139/150 | Loss 0.0027 | Win/lose count 14.5/1.0 (13.5)
# Epoch 140/150 | Loss 0.0022 | Win/lose count 17.5/5.0 (12.5)
# Epoch 141/150 | Loss 0.0023 | Win/lose count 7.0/1.0 (6.0)
# Epoch 142/150 | Loss 0.0079 | Win/lose count 13.0/3.0 (10.0)
# Epoch 143/150 | Loss 0.0009 | Win/lose count 23.0/5.0 (18.0)
# Epoch 144/150 | Loss 0.0022 | Win/lose count 14.0/5.0 (9.0)
# Epoch 145/150 | Loss 0.0024 | Win/lose count 21.0/6.0 (15.0)
# Epoch 146/150 | Loss 0.0025 | Win/lose count 26.5/3.0 (23.5)
# Epoch 147/150 | Loss 0.0509 | Win/lose count 15.0/2.0 (13.0)
# Epoch 148/150 | Loss 0.0033 | Win/lose count 23.5/2.0 (21.5)
# Epoch 149/150 | Loss 0.0022 | Win/lose count 9.0/1.0 (8.0)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# ***
# ***
# __Question 9__ Test both algorithms and compare their performances. Which issue(s) do you observe? Observe also different behaviors by changing the temperature.

# %%
env = Environment(grid_size=size, max_time=T,temperature=0.3)
agent_cnn = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='cnn_trainmodel.h5',name_model='cnn_trainmodel.json')

agent_fc = DQN_FC(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32)
agent_cnn.load(name_weights='fc_trainmodel.h5',name_model='fc_trainmodel.json')
print('Test of the CNN')
test(agent_cnn,env,epochs_test,prefix='cnn_test')
print('Test of the FC')
test(agent_fc,env,epochs_test,prefix='fc_test')
# Out:
# Test of the CNN
# Win/lose count 1.0/1.0. Average score (0.0)
# Win/lose count 1.5/0. Average score (0.75)
# Win/lose count 0/0. Average score (0.5)
# Win/lose count 2.5/0. Average score (1.0)
# Win/lose count 1.0/0. Average score (1.0)
# Win/lose count 4.0/1.0. Average score (1.3333333333333333)
# Win/lose count 0.5/0. Average score (1.2142857142857142)
# Win/lose count 1.0/0. Average score (1.1875)
# Win/lose count 0/0. Average score (1.0555555555555556)
# Win/lose count 1.5/3.0. Average score (0.8)
# Final score: 0.8
# Test of the FC
# Win/lose count 1.5/1.0. Average score (0.5)
# Win/lose count 0/1.0. Average score (-0.25)
# Win/lose count 0.5/2.0. Average score (-0.6666666666666666)
# Win/lose count 0/0. Average score (-0.5)
# Win/lose count 1.0/3.0. Average score (-0.8)
# Win/lose count 1.0/1.0. Average score (-0.6666666666666666)
# Win/lose count 0/1.0. Average score (-0.7142857142857143)
# Win/lose count 1.5/3.0. Average score (-0.8125)
# Win/lose count 2.0/3.0. Average score (-0.8333333333333334)
# Win/lose count 1.0/7.0. Average score (-1.35)
# Final score: -1.35

# %%
HTML(display_videos('cnn_test10.mp4'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-70-6258079ce82e> in <module>()
# ----> 1 HTML(display_videos('cnn_test10.mp4'))
#
# <ipython-input-68-3eefef004da2> in display_videos(name)
#       8 # display videos
#       9 def display_videos(name):
# ---> 10     video = io.open(name, 'r+b').read()
#      11     encoded = base64.b64encode(video)
#      12     return '''<video alt="test" controls>
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cnn_test10.mp4'

# %%
HTML(display_videos('fc_test10.mp4'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-71-3b7449c17544> in <module>()
# ----> 1 HTML(display_videos('fc_test10.mp4'))
#
# <ipython-input-68-3eefef004da2> in display_videos(name)
#       8 # display videos
#       9 def display_videos(name):
# ---> 10     video = io.open(name, 'r+b').read()
#      11     encoded = base64.b64encode(video)
#      12     return '''<video alt="test" controls>
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fc_test10.mp4'

# %% [markdown]
# The cnn performs better than the neural network. The problem is that epsilon is fixed so that even when the model is well trained performance can be hurt by the random steps. Also in the early videos during training we can clearly observe that the rat tends to oscillate around his position because punitions (-1) or worse than rewards (0.5) so overall the "not moving" strategy is not that bad

# %% [markdown]
# ***
#
# The algorithm tends to not explore the map which can be an issue. We propose two ideas in order to encourage exploration:
# 1. Incorporating a decreasing $\epsilon$-greedy exploration. You can use the method ```set_epsilon```
# 2. Append via the environment a new state that describes if a cell has been visited or not
#
# ***
# __Question 10__ Design a new ```train_explore``` function and environment class ```EnvironmentExploring``` to tackle the issue of exploration.

# %%
def train_explore(agent,env,epoch,prefix=''):
    # Number of won games
    score = 0
    loss = 0

    for e in range(epoch):
        agent.set_epsilon((-0.5/epoch)*e + 0.5)
        # At each epoch, we restart to a fresh game and get the initial state
        state = env.reset()
        # This assumes that the games will terminate
        game_over = False

        win = 0
        lose = 0

        while not game_over:
            # The agent performs an action
            action = agent.act(state)

            # Apply an action to the environment, get the next state, the reward
            # and if the games end
            prev_state = state
            state, reward, game_over = env.act(action)

            # Update the counters
            if reward > 0:
                win = win + reward
            if reward < 0:
                lose = lose -reward

            # Apply the reinforcement strategy
            loss = agent.reinforce(prev_state, state,  action, reward, game_over)

        # Save as a mp4
        if e % 10 == 0:
            env.draw(prefix+str(e))

        # Update stats
        score += win-lose

        print("Epoch {:03d}/{:03d} | Loss {:.4f} | Win/lose count {}/{} ({})"
              .format(e, epoch, loss, win, lose, win-lose))
        agent.save(name_weights=prefix+'model.h5',name_model=prefix+'model.json')
        
class EnvironmentExploring(object):
    def __init__(self, grid_size=10, max_time=500, temperature=0.1):
        grid_size = grid_size+4
        self.grid_size = grid_size
        self.max_time = max_time
        self.temperature = temperature

        #board on which one plays
        self.board = np.zeros((grid_size,grid_size))
        self.position = np.zeros((grid_size,grid_size))
        self.malus_position = np.zeros((grid_size,grid_size))

        # coordinate of the cat
        self.x = 0
        self.y = 1

        # self time
        self.t = 0

        self.scale=16

        self.to_draw = np.zeros((max_time+2, grid_size*self.scale, grid_size*self.scale, 3))


    def draw(self,e):
        skvideo.io.vwrite(str(e) + '.mp4', self.to_draw)

    def get_frame(self,t):
        b = np.zeros((self.grid_size,self.grid_size,3))+128
        b[self.board>0,0] = 256
        b[self.board < 0, 2] = 256
        b[self.x,self.y,:]=256
        b[-2:,:,:]=0
        b[:,-2:,:]=0
        b[:2,:,:]=0
        b[:,:2,:]=0
        
        b =  cv2.resize(b, None, fx=self.scale, fy=self.scale, interpolation=cv2.INTER_NEAREST)

        self.to_draw[t,:,:,:]=b


    def act(self, action):
        """This function returns the new state, reward and decides if the
        game ends."""

        self.get_frame(int(self.t))

        self.position = np.zeros((self.grid_size, self.grid_size))

        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1

        self.position[self.x, self.y] = 1
        if action == 0:
            if self.x == self.grid_size-3:
                self.x = self.x-1
            else:
                self.x = self.x + 1
        elif action == 1:
            if self.x == 2:
                self.x = self.x+1
            else:
                self.x = self.x-1
        elif action == 2:
            if self.y == self.grid_size - 3:
                self.y = self.y - 1
            else:
                self.y = self.y + 1
        elif action == 3:
            if self.y == 2:
                self.y = self.y + 1
            else:
                self.y = self.y - 1
        else:
            RuntimeError('Error: action not recognized')

        self.t = self.t + 1
        reward = -self.malus_position[self.x, self.y]
        self.malus_position[self.x, self.y] = 0.1
        reward = reward +  self.board[self.x, self.y]
        self.board[self.x, self.y] = 0
        game_over = self.t > self.max_time
        state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1), self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)
        state = state[self.x-2:self.x+3,self.y-2:self.y+3,:]

        return state, reward, game_over

    def reset(self):
        """This function resets the game and returns the initial state"""

        self.x = np.random.randint(3, self.grid_size-3, size=1)[0]
        self.y = np.random.randint(3, self.grid_size-3, size=1)[0]


        bonus = 0.5*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        bonus = bonus.reshape(self.grid_size,self.grid_size)

        malus = -1.0*np.random.binomial(1,self.temperature,size=self.grid_size**2)
        malus = malus.reshape(self.grid_size, self.grid_size)

        self.to_draw = np.zeros((self.max_time+2, self.grid_size*self.scale, self.grid_size*self.scale, 3))


        malus[bonus>0]=0

        self.board = bonus + malus

        self.position = np.zeros((self.grid_size, self.grid_size))
        self.position[0:2,:]= -1
        self.position[:,0:2] = -1
        self.position[-2:, :] = -1
        self.position[-2:, :] = -1
        self.board[self.x,self.y] = 0
        self.t = 0
        
        self.malus_position = np.zeros((self.grid_size, self.grid_size))

        state = np.concatenate(( self.malus_position.reshape(self.grid_size, self.grid_size,1),
                               self.board.reshape(self.grid_size, self.grid_size,1),
                        self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

        state = state[self.x - 2:self.x + 3, self.y - 2:self.y + 3, :]
        return state
    
## use those samples of code:
#In train explore:

#state, reward, game_over = env.act(action, train=True)

## In Environment exploring:
# You will have to change n_state to 3 because you will use one more layer!

#reward = 0
#if train:
    #reward = -self.malus_position[self.x, self.y]
#self.malus_position[self.x, self.y] = 0.1

#reward = reward + self.board[self.x, self.y]
# 3 "feature" states instead of 2
#state = np.concatenate((self.malus_position.reshape(self.grid_size, self.grid_size,1),
                                #self.board.reshape(self.grid_size, self.grid_size,1),
                        #self.position.reshape(self.grid_size, self.grid_size,1)),axis=2)

# %%
# Training
env = EnvironmentExploring(grid_size=size, max_time=T, temperature=0.3)
agent = DQN_CNN(size, lr=.1, epsilon = 0.1, memory_size=2000, batch_size = 32,n_state=3)
train_explore(agent, env, epochs_train, prefix='cnn_train_explore')
HTML(display_videos('cnn_train_explore10.mp4'))
# Out:
# Epoch 000/100 | Loss 0.0052 | Win/lose count 6.5/25.600000000000083 (-19.100000000000083)
# Epoch 001/100 | Loss 0.0080 | Win/lose count 13.0/26.5000000000001 (-13.5000000000001)
# Epoch 002/100 | Loss 0.0087 | Win/lose count 8.5/26.200000000000113 (-17.700000000000113)
# Epoch 003/100 | Loss 0.0053 | Win/lose count 18.0/20.500000000000036 (-2.5000000000000355)
# Epoch 004/100 | Loss 0.0115 | Win/lose count 11.0/22.90000000000005 (-11.900000000000048)
# Epoch 005/100 | Loss 0.0085 | Win/lose count 11.5/23.600000000000076 (-12.100000000000076)
# Epoch 006/100 | Loss 0.0048 | Win/lose count 16.5/20.800000000000033 (-4.300000000000033)
# Epoch 007/100 | Loss 0.0578 | Win/lose count 25.5/18.599999999999994 (6.900000000000006)
# Epoch 008/100 | Loss 0.0587 | Win/lose count 10.5/17.89999999999999 (-7.3999999999999915)
# Epoch 009/100 | Loss 0.0072 | Win/lose count 10.5/19.900000000000027 (-9.400000000000027)
# Epoch 010/100 | Loss 0.0052 | Win/lose count 8.0/20.800000000000022 (-12.800000000000022)
# Epoch 011/100 | Loss 0.0071 | Win/lose count 14.5/17.599999999999984 (-3.0999999999999837)
# Epoch 012/100 | Loss 0.0072 | Win/lose count 16.0/16.49999999999997 (-0.4999999999999716)
# Epoch 013/100 | Loss 0.0051 | Win/lose count 20.5/19.600000000000026 (0.8999999999999737)
# Epoch 014/100 | Loss 0.0505 | Win/lose count 15.5/23.400000000000034 (-7.900000000000034)
# Epoch 015/100 | Loss 0.0051 | Win/lose count 14.5/22.800000000000054 (-8.300000000000054)
# Epoch 016/100 | Loss 0.0038 | Win/lose count 20.0/19.600000000000016 (0.39999999999998437)
# Epoch 017/100 | Loss 0.0048 | Win/lose count 14.5/21.900000000000027 (-7.400000000000027)
# Epoch 018/100 | Loss 0.0046 | Win/lose count 16.0/20.499999999999993 (-4.499999999999993)
# Epoch 019/100 | Loss 0.0167 | Win/lose count 19.0/21.90000000000002 (-2.90000000000002)
# Epoch 020/100 | Loss 0.0081 | Win/lose count 18.5/21.499999999999996 (-2.9999999999999964)
# Epoch 021/100 | Loss 0.0086 | Win/lose count 18.0/21.500000000000046 (-3.500000000000046)
# Epoch 022/100 | Loss 0.0064 | Win/lose count 20.0/19.600000000000012 (0.3999999999999879)
# Epoch 023/100 | Loss 0.0077 | Win/lose count 18.0/19.80000000000003 (-1.8000000000000291)
# Epoch 024/100 | Loss 0.0043 | Win/lose count 21.5/15.399999999999968 (6.100000000000032)
# Epoch 025/100 | Loss 0.0063 | Win/lose count 20.0/17.49999999999998 (2.5000000000000213)
# Epoch 026/100 | Loss 0.0060 | Win/lose count 24.5/21.900000000000038 (2.5999999999999623)
# Epoch 027/100 | Loss 0.0064 | Win/lose count 23.0/17.69999999999999 (5.300000000000011)
# Epoch 028/100 | Loss 0.0060 | Win/lose count 16.0/18.600000000000005 (-2.600000000000005)
# Epoch 029/100 | Loss 0.0379 | Win/lose count 26.0/17.800000000000004 (8.199999999999996)
# Epoch 030/100 | Loss 0.0091 | Win/lose count 14.0/18.29999999999997 (-4.299999999999969)
# Epoch 031/100 | Loss 0.0368 | Win/lose count 16.0/16.99999999999998 (-0.9999999999999787)
# Epoch 032/100 | Loss 0.0380 | Win/lose count 18.0/18.39999999999997 (-0.39999999999997016)
# Epoch 033/100 | Loss 0.0059 | Win/lose count 19.5/18.800000000000015 (0.6999999999999851)
# Epoch 034/100 | Loss 0.0111 | Win/lose count 25.0/21.6 (3.3999999999999986)
# Epoch 035/100 | Loss 0.0056 | Win/lose count 10.5/20.60000000000004 (-10.10000000000004)
# Epoch 036/100 | Loss 0.0055 | Win/lose count 12.0/22.00000000000005 (-10.00000000000005)
# Epoch 037/100 | Loss 0.0051 | Win/lose count 23.0/19.79999999999999 (3.20000000000001)
# Epoch 038/100 | Loss 0.0127 | Win/lose count 23.0/18.7 (4.300000000000001)
# Epoch 039/100 | Loss 0.0109 | Win/lose count 20.5/22.200000000000042 (-1.700000000000042)
# Epoch 040/100 | Loss 0.0108 | Win/lose count 22.0/18.100000000000012 (3.899999999999988)
# Epoch 041/100 | Loss 0.0071 | Win/lose count 17.5/21.600000000000048 (-4.100000000000048)
# Epoch 042/100 | Loss 0.0101 | Win/lose count 20.5/17.39999999999999 (3.1000000000000085)
# Epoch 043/100 | Loss 0.0084 | Win/lose count 18.5/20.800000000000026 (-2.3000000000000256)
# Epoch 044/100 | Loss 0.0075 | Win/lose count 26.0/18.299999999999997 (7.700000000000003)
# Epoch 045/100 | Loss 0.0067 | Win/lose count 18.5/17.59999999999998 (0.9000000000000199)
# Epoch 046/100 | Loss 0.0098 | Win/lose count 15.0/18.900000000000016 (-3.9000000000000163)
# Epoch 047/100 | Loss 0.0087 | Win/lose count 18.5/23.900000000000034 (-5.400000000000034)
# Epoch 048/100 | Loss 0.0072 | Win/lose count 22.0/20.200000000000024 (1.7999999999999758)
# Epoch 049/100 | Loss 0.0096 | Win/lose count 19.5/15.399999999999972 (4.100000000000028)
# Epoch 050/100 | Loss 0.0113 | Win/lose count 22.5/16.199999999999978 (6.300000000000022)
# Epoch 051/100 | Loss 0.0122 | Win/lose count 25.5/16.59999999999998 (8.90000000000002)
# Epoch 052/100 | Loss 0.0072 | Win/lose count 20.5/18.9 (1.6000000000000014)
# Epoch 053/100 | Loss 0.0112 | Win/lose count 12.5/19.600000000000005 (-7.100000000000005)
# Epoch 054/100 | Loss 0.0144 | Win/lose count 24.0/17.199999999999996 (6.800000000000004)
# Epoch 055/100 | Loss 0.0094 | Win/lose count 20.5/18.900000000000002 (1.5999999999999979)
# Epoch 056/100 | Loss 0.0081 | Win/lose count 24.0/20.50000000000003 (3.4999999999999716)
# Epoch 057/100 | Loss 0.0098 | Win/lose count 25.0/12.999999999999973 (12.000000000000027)
# Epoch 058/100 | Loss 0.0103 | Win/lose count 21.0/18.299999999999997 (2.700000000000003)
# Epoch 059/100 | Loss 0.0060 | Win/lose count 30.0/13.399999999999983 (16.600000000000016)
# Epoch 060/100 | Loss 0.0125 | Win/lose count 16.5/18.899999999999995 (-2.399999999999995)
# Epoch 061/100 | Loss 0.0074 | Win/lose count 21.0/15.499999999999975 (5.500000000000025)
# Epoch 062/100 | Loss 0.0062 | Win/lose count 8.5/21.800000000000047 (-13.300000000000047)
# Epoch 063/100 | Loss 0.0100 | Win/lose count 19.0/16.899999999999984 (2.1000000000000156)
# Epoch 064/100 | Loss 0.0115 | Win/lose count 22.0/17.9 (4.100000000000001)
# Epoch 065/100 | Loss 0.0092 | Win/lose count 19.0/17.09999999999998 (1.90000000000002)
# Epoch 066/100 | Loss 0.0075 | Win/lose count 25.0/12.599999999999975 (12.400000000000025)
# Epoch 067/100 | Loss 0.0057 | Win/lose count 28.5/10.799999999999985 (17.700000000000017)
# Epoch 068/100 | Loss 0.0118 | Win/lose count 23.5/15.39999999999997 (8.10000000000003)
# Epoch 069/100 | Loss 0.0155 | Win/lose count 21.0/20.60000000000003 (0.39999999999997016)
# Epoch 070/100 | Loss 0.0228 | Win/lose count 26.0/16.39999999999998 (9.60000000000002)
# Epoch 071/100 | Loss 0.0475 | Win/lose count 16.0/17.499999999999993 (-1.499999999999993)
# Epoch 072/100 | Loss 0.0104 | Win/lose count 26.0/11.199999999999976 (14.800000000000024)
# Epoch 073/100 | Loss 0.0162 | Win/lose count 16.5/13.299999999999967 (3.200000000000033)
# Epoch 074/100 | Loss 0.0083 | Win/lose count 19.5/17.499999999999996 (2.0000000000000036)
# Epoch 075/100 | Loss 0.0266 | Win/lose count 26.5/12.399999999999975 (14.100000000000025)
# Epoch 076/100 | Loss 0.0103 | Win/lose count 12.5/14.799999999999963 (-2.2999999999999634)
# Epoch 077/100 | Loss 0.0077 | Win/lose count 26.5/12.999999999999979 (13.500000000000021)
# Epoch 078/100 | Loss 0.0064 | Win/lose count 22.0/15.299999999999976 (6.700000000000024)
# Epoch 079/100 | Loss 0.0029 | Win/lose count 19.0/15.999999999999973 (3.0000000000000266)
# Epoch 080/100 | Loss 0.0092 | Win/lose count 13.0/15.799999999999967 (-2.799999999999967)
# Epoch 081/100 | Loss 0.0090 | Win/lose count 20.0/14.299999999999972 (5.700000000000028)
# Epoch 082/100 | Loss 0.0139 | Win/lose count 18.0/15.499999999999964 (2.5000000000000355)
# Epoch 083/100 | Loss 0.0208 | Win/lose count 20.0/14.999999999999966 (5.000000000000034)
# Epoch 084/100 | Loss 0.0372 | Win/lose count 11.5/18.800000000000008 (-7.300000000000008)
# Epoch 085/100 | Loss 0.0223 | Win/lose count 17.5/13.499999999999972 (4.000000000000028)
# Epoch 086/100 | Loss 0.0142 | Win/lose count 11.0/18.200000000000003 (-7.200000000000003)
# Epoch 087/100 | Loss 0.0452 | Win/lose count 23.0/11.499999999999979 (11.500000000000021)
# Epoch 088/100 | Loss 0.0087 | Win/lose count 25.5/12.199999999999974 (13.300000000000026)
# Epoch 089/100 | Loss 0.0073 | Win/lose count 20.5/14.399999999999974 (6.100000000000026)
# Epoch 090/100 | Loss 0.0105 | Win/lose count 24.0/12.499999999999972 (11.500000000000028)
# Epoch 091/100 | Loss 0.0102 | Win/lose count 17.0/14.599999999999968 (2.4000000000000323)
# Epoch 092/100 | Loss 0.0054 | Win/lose count 20.0/13.299999999999974 (6.700000000000026)
# Epoch 093/100 | Loss 0.0122 | Win/lose count 16.5/12.69999999999997 (3.800000000000029)
# Epoch 094/100 | Loss 0.0094 | Win/lose count 14.0/13.799999999999967 (0.20000000000003304)
# Epoch 095/100 | Loss 0.0125 | Win/lose count 18.0/12.599999999999975 (5.400000000000025)
# Epoch 096/100 | Loss 0.0084 | Win/lose count 14.5/16.099999999999966 (-1.599999999999966)
# Epoch 097/100 | Loss 0.0100 | Win/lose count 27.5/10.099999999999984 (17.400000000000016)
# Epoch 098/100 | Loss 0.0046 | Win/lose count 15.5/12.499999999999972 (3.0000000000000284)
# Epoch 099/100 | Loss 0.0180 | Win/lose count 20.5/13.199999999999969 (7.300000000000031)
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# Evaluation
test(agent,env,epochs_test,prefix='cnn_test_explore')
HTML(display_videos('cnn_test_explore10.mp4'))
# Out:
# Win/lose count 13.5/13.799999999999967. Average score (-0.29999999999996696)
# Win/lose count 13.0/14.499999999999964. Average score (-0.8999999999999657)
# Win/lose count 16.5/13.499999999999968. Average score (0.4000000000000335)
# Win/lose count 25.0/11.099999999999977. Average score (3.7750000000000314)
# Win/lose count 15.5/15.099999999999962. Average score (3.1000000000000325)
# Win/lose count 16.5/14.099999999999966. Average score (2.9833333333333663)
# Win/lose count 2.5/18.099999999999987. Average score (0.3285714285714586)
# Win/lose count 23.5/12.599999999999971. Average score (1.6500000000000299)
# Win/lose count 23.5/11.89999999999998. Average score (2.755555555555584)
# Win/lose count 9.0/17.69999999999998. Average score (1.6100000000000272)
# Final score: 1.6100000000000272
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-77-598634141cce> in <module>()
#       1 # Evaluation
#       2 test(agent,env,epochs_test,prefix='cnn_test_explore')
# ----> 3 HTML(display_videos('cnn_test_explore10.mp4'))
#
# <ipython-input-68-3eefef004da2> in display_videos(name)
#       8 # display videos
#       9 def display_videos(name):
# ---> 10     video = io.open(name, 'r+b').read()
#      11     encoded = base64.b64encode(video)
#      12     return '''<video alt="test" controls>
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cnn_test_explore10.mp4'

# %% [markdown]
# ***
# ***
# __BONUS question__ Use the expert DQN from the previous question to generate some winning games. Train a model that mimicks its behavior. Compare the performances.

# %% [markdown]
# ***
